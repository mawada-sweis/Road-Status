# %%
# Standard library
import sys
import os
import re

# Related third party imports
import pandas as pd

# Local imports
target = os.path.abspath(os.path.abspath(''))
while (target.split("\\")[-1] != "Road"):
    target = os.path.dirname(target)
sys.path.append(target)
from source.features import transformation as TF

# %%
data = pd.read_csv('../data/interim/cleaned_data.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0      id                                         message  \
# 0           1  409427                          حواره للخارج من نابلس
# 1           3  409429                         حوارة في عليها مستوطنين
# 2           5  409431                     كيف طريق من طوباس لرام الله
# 3           6  409432                                            سلام
# 4           8  409434                                 شو وضع المربعه
# 5          10  409436                                     حوارة سالكة
# 6          11  409437                             في ازمة عحاجز حوارة
# 7          12  409438                     شباب كيف الوضع صرة ودير شرف
# 8          13  409439  hollowredcircleحاجز حواره سالك حركه سير طبيعيه
# 9          14  409440                                        سالك صره
#
#       from_id  year  month  day  hour  minute  second                  reply
# 0   325418964  2023      3    7    13      50       2              سالك سالك
# 1  5633332941  2023      3    7    13      50      18                لا مافب
# 2  5661074759  2023      3    7    13      50      35                    NaN
# 3  5593129285  2023      3    7    13      50      37                    NaN
# 4  1507939991  2023      3    7    13      50      39        في حاجز بس سالك
# 5  5190660308  2023      3    7    13      50      57  سالكة حركة سير طبيعية
# 6  5403676950  2023      3    7    13      50      58                    NaN
# 7  2122512266  2023      3    7    13      51       8              لهسه مناح
# 8  1827882971  2023      3    7    13      51      13                    NaN
# 9  1827882971  2023      3    7    13      51      17                    NaN

# %%
data['Huara_barrier'] = data['message'].astype(str).apply(TF.huara_matches)

data.head(10)
# Out:
#    Unnamed: 0      id                                         message  \
# 0           1  409427                          حواره للخارج من نابلس
# 1           3  409429                         حوارة في عليها مستوطنين
# 2           5  409431                     كيف طريق من طوباس لرام الله
# 3           6  409432                                            سلام
# 4           8  409434                                 شو وضع المربعه
# 5          10  409436                                     حوارة سالكة
# 6          11  409437                             في ازمة عحاجز حوارة
# 7          12  409438                     شباب كيف الوضع صرة ودير شرف
# 8          13  409439  hollowredcircleحاجز حواره سالك حركه سير طبيعيه
# 9          14  409440                                        سالك صره
#
#       from_id  year  month  day  hour  minute  second                  reply  \
# 0   325418964  2023      3    7    13      50       2              سالك سالك
# 1  5633332941  2023      3    7    13      50      18                لا مافب
# 2  5661074759  2023      3    7    13      50      35                    NaN
# 3  5593129285  2023      3    7    13      50      37                    NaN
# 4  1507939991  2023      3    7    13      50      39        في حاجز بس سالك
# 5  5190660308  2023      3    7    13      50      57  سالكة حركة سير طبيعية
# 6  5403676950  2023      3    7    13      50      58                    NaN
# 7  2122512266  2023      3    7    13      51       8              لهسه مناح
# 8  1827882971  2023      3    7    13      51      13                    NaN
# 9  1827882971  2023      3    7    13      51      17                    NaN
#
#    Huara_barrier
# 0              1
# 1              1
# 2              0
# 3              0
# 4              0
# 5              1
# 6              1
# 7              0
# 8              1
# 9              0

# %%
data['message_type'] = TF.categorize_message(data['reply'], data['message'])

# %%
data
# Out:
#        Unnamed: 0      id                      message     from_id  year  \
# 0               1  409427       حواره للخارج من نابلس    325418964  2023
# 1               3  409429      حوارة في عليها مستوطنين  5633332941  2023
# 2               5  409431  كيف طريق من طوباس لرام الله  5661074759  2023
# 3               6  409432                         سلام  5593129285  2023
# 4               8  409434              شو وضع المربعه   1507939991  2023
# ...           ...     ...                          ...         ...   ...
# 12458       17300  428596          شو وضع طريق عصير 17  5452576221  2023
# 12459       17301  428597                 كيف طريق صرة   939291539  2023
# 12460       17302  428598                و دوار كدوميم   939291539  2023
# 12461       17303  428599                   شو وضع dso  5767031256  2023
# 12462       17305  428601               واد قانا سالك   2111855532  2023
#
#        month  day  hour  minute  second            reply  Huara_barrier  \
# 0          3    7    13      50       2        سالك سالك              1
# 1          3    7    13      50      18          لا مافب              1
# 2          3    7    13      50      35              NaN              0
# 3          3    7    13      50      37              NaN              0
# 4          3    7    13      50      39  في حاجز بس سالك              0
# ...      ...  ...   ...     ...     ...              ...            ...
# 12458      3   16    20      50      33              NaN              0
# 12459      3   16    20      53      57    جيت صرة سالكة              0
# 12460      3   16    20      54       7              NaN              0
# 12461      3   16    20      55      10              NaN              0
# 12462      3   16    21       1      20              NaN              0
#
#       message_type
# 0         answered
# 1         answered
# 2         question
# 3         question
# 4         answered
# ...            ...
# 12458          NaN
# 12459          NaN
# 12460          NaN
# 12461          NaN
# 12462          NaN
#
# [12463 rows x 13 columns]
